# %%
import numpy as np
import matplotlib.pyplot as plt


# %matplotlib inline


tsquared_array = np.array([1.77, 1.69, 1.61, 1.37])
radius_array = np.array([ 0.2040, 0.1870, 0.1680, 0.1560 ])
m, b = np.polyfit(x, y, 1)

plt.xlabel('radius (m)')
plt.ylabel('T^2 (s)')
plt.title('Radius versus T squared graph')


y=tsquared_array
x=radius_array

print(m)
print(b)

plt.plot(x, y, 'o')
plt.plot(x, m*x + b)
# Out:
# 7.589169000933715
# 0.25343604108309864
